# %%
try: # install all dependencies in colab
    import google.colab
    # !sudo apt-get update -y
    # !sudo apt-get install -y libnvidia-gl-555 vulkan-tools glslang-tools vulkan-validationlayers-dev
    # !pip install pyav==13.1.0
    # !pip install git+https://github.com/lleonart1984/vk_project.git
except:
    print("Executing locally")
# Out:
# Executing locally

# %%
import torch
import vk

# %%
device = vk.create_device(0, enable_validation_layers=False)

# %%
t = torch.from_dlpack(device.allocate_tensor_dlpack([100], scalar_type=vk.ScalarType.FLOAT32,
                                                    location=vk.MemoryLocation.HOST))
